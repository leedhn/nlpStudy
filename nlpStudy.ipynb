# %% [markdown]
# <a href="https://colab.research.google.com/github/leedhn/nlpStudy/blob/main/nlpStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install parlai
# Out:
# ...
#      |████████████████████████████████| 1.4MB 13.9MB/s
# ...
#      |████████████████████████████████| 3.2MB 55.6MB/s
# ...
#      |████████████████████████████████| 61kB 4.3MB/s
# ...
#      |████████████████████████████████| 204kB 50.9MB/s
# ...
#      |████████████████████████████████| 51kB 4.0MB/s
# ...
#      |████████████████████████████████| 163kB 37.5MB/s
# ...
#      |████████████████████████████████| 81kB 4.4MB/s
# ...
#      |████████████████████████████████| 7.3MB 50.6MB/s
# ...
#      |████████████████████████████████| 133kB 59.0MB/s
# ...
#      |████████████████████████████████| 245kB 63.1MB/s
# ...
#      |████████████████████████████████| 40kB 2.6MB/s
# ...
#      |████████████████████████████████| 51kB 3.6MB/s
# ...
#      |████████████████████████████████| 133kB 38.6MB/s
# ...
#      |████████████████████████████████| 133kB 47.3MB/s
# ...
#      |████████████████████████████████| 215kB 50.1MB/s
# ...
#      |████████████████████████████████| 133kB 37.9MB/s
# ...
#      |████████████████████████████████| 2.8MB 52.5MB/s
# ...

# %%
# !parlai display_data --task commonsenseqa
# Out:
# 06:42:03 | Opt:
# 06:42:03 |     allow_missing_init_opts: False
# 06:42:03 |     batchsize: 1
# 06:42:03 |     datapath: /usr/local/lib/python3.7/dist-packages/data
# 06:42:03 |     datatype: train:ordered
# 06:42:03 |     dict_class: None
# 06:42:03 |     display_add_fields:
# 06:42:03 |     download_path: None
# 06:42:03 |     dynamic_batching: None
# 06:42:03 |     hide_labels: False
# 06:42:03 |     ignore_agent_reply: True
# 06:42:03 |     image_cropsize: 224
# 06:42:03 |     image_mode: raw
# 06:42:03 |     image_size: 256
# 06:42:03 |     init_model: None
# 06:42:03 |     init_opt: None
# 06:42:03 |     loglevel: info
# 06:42:03 |     max_display_len: 1000
# 06:42:03 |     model: None
# 06:42:03 |     model_file: None
# 06:42:03 |     multitask_weights: [1]
# 06:42:03 |     mutators: None
# 06:42:03 |     num_examples: 10
# 06:42:03 |     override: "{'task': 'commonsenseqa'}"
# 06:42:03 |     parlai_home: /usr/local/lib/python3.7/dist-packages
# ...
